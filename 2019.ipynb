# %% [markdown]
# ## Limpeza de dados Cartola ano 2019

# %%
from pyspark.sql import HiveContext
from pyspark.sql.types import IntegerType, StringType, FloatType
from pyspark.sql.functions import lower, col, lit, regexp_replace, trim, substring, when, expr, udf, count, sum, monotonically_increasing_id
import pandas as pd
import json
import requests

# Confirguração para não sobrescrever DF
spark.conf.set('spark.sql.sources.partitionOverwriteMode', 'dynamic')

# %% [markdown]
# ## Funções Custonmizadas

# %%
def remove_after_hiphen(team_name):
    if team_name.startswith('atletico') or team_name.startswith('atl')  or team_name.startswith('Atl') or team_name.startswith('Ath'):
        return team_name
    else:
        return team_name.split('-', 1)[0]

# %%
#Remove dos valores das Strings o que estiver após os hiphen
remove_hiphen_udf = udf(remove_after_hiphen, StringType())
#partidas_2014_ct = partidas_2014_df.withColumn('away_team', remove_hiphen_udf(partidas_2014_df['away_team']))

# %% [markdown]
# ## Jogadores

# %%
#Carrega arquivo CSV Jogadores
jogadores_2019_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2019/2019-medias-jogadores.csv", header=True)
sorted_jogadores_2019_df = jogadores_2019_df.sort(jogadores_2019_df.player_id.asc())

# %%
#Carrega arquivo Posicoes_ID
posicoes_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/posicoes_ids.csv", header=True)
posicoes_df.toPandas()
# Out:
#   _c0 Cod  Position abbr
# 0   1   1   Goleiro  gol
# 1   2   2   Lateral  lat
# 2   3   3  Zagueiro  zag
# 3   4   4      Meia  mei
# 4   5   5  Atacante  ata
# 5   6   6   Técnico  tec

# %%
#Adiciona coluna ANO = 2019
jogadores_2019_ano = sorted_jogadores_2019_df.withColumn('year', lit(2019))
jogadores_2019_ano.toPandas()
# Out:
#       player_slug player_id player_nickname player_team player_position  \
# 0         rickson    100002         Rickson         263             mei
# 1         lincoln    100065         Lincoln         262             ata
# 2      igor-gomes    100084      Igor Gomes         276             mei
# 3        pedrinho    100103        Pedrinho         293             ata
# 4          thuler    100125          Thuler         262             zag
# ..            ...       ...             ...         ...             ...
# 687         chara     99891           Chará         282             ata
# 688  luan-pereira     99900    Luan Pereira         314             mei
# 689  lucas-campos     99903    Lucas Campos         263             ata
# 690      ezequiel     99915        Ezequiel         283             ata
# 691       patrick     99918         Patrick         284             mei
#
#     price_cartoletas         score_mean score_no_cleansheets_mean  \
# 0                1.4  0.433333333333333         0.433333333333333
# 1               5.89   4.00909090909091          4.00909090909091
# 2               2.47   1.87777777777778          1.87777777777778
# 3               1.88   1.36666666666667          1.36666666666667
# 4               3.24   1.80769230769231        -0.115384615384615
# ..               ...                ...                       ...
# 687            11.57   4.22777777777778          4.22777777777778
# 688             2.34                0.9                       0.9
# 689             1.91               1.45                      1.45
# 690             3.97   1.62857142857143          1.62857142857143
# 691             4.17   1.95555555555556          1.95555555555556
#
#        diff_home_away_s n_games  ...              I_mean            FS_mean  \
# 0     -1.38283487393904       6  ...                   0   1.16666666666667
# 1       1.8919422869998      11  ...  0.0909090909090909  0.727272727272727
# 2     0.413571458750421      27  ...   0.037037037037037   1.14814814814815
# 3     -1.13910991608839       6  ...   0.333333333333333  0.333333333333333
# 4     0.316909312629831      13  ...                   0  0.307692307692308
# ..                  ...     ...  ...                 ...                ...
# 687   0.894885641247105      18  ...   0.222222222222222   1.38888888888889
# 688  -0.689259442920505      17  ...                   0  0.941176470588235
# 689   0.163710767695131      10  ...                   0                1.3
# 690  -0.232526928931772      14  ...  0.0714285714285714                  1
# 691   -1.21788970044415      18  ...                   0  0.888888888888889
#
#                FF_mean              G_mean DD_mean DP_mean      status  \
# 0    0.166666666666667                   0       0       0        Nulo
# 1    0.545454545454545   0.272727272727273       0       0        Nulo
# 2    0.296296296296296  0.0740740740740741       0       0        Nulo
# 3                  0.5                   0       0       0      Dúvida
# 4                    0                   0       0       0        Nulo
# ..                 ...                 ...     ...     ...         ...
# 687  0.666666666666667   0.166666666666667       0       0  Contundido
# 688  0.294117647058824                   0       0       0    Provável
# 689                0.4                   0       0       0        Nulo
# 690  0.214285714285714                   0       0       0        Nulo
# 691  0.166666666666667   0.111111111111111       0       0    Provável
#
#     price_diff last_points  year
# 0         0.25        -0.3  2019
# 1         1.32        13.7  2019
# 2        -0.42         3.7  2019
# 3         0.98           6  2019
# 4        -0.05         3.5  2019
# ..         ...         ...   ...
# 687      -0.44         3.6  2019
# 688      -0.08         0.2  2019
# 689       0.23           2  2019
# 690      -0.24         0.4  2019
# 691       1.95        12.4  2019
#
# [692 rows x 27 columns]

# %%
jogadores_2019_ano = jogadores_2019_ano['player_id', 'player_nickname', 'player_team', 'player_position']
jogadores_2019_ano.toPandas()
# Out:
#     player_id player_nickname player_team player_position
# 0      100002         Rickson         263             mei
# 1      100065         Lincoln         262             ata
# 2      100084      Igor Gomes         276             mei
# 3      100103        Pedrinho         293             ata
# 4      100125          Thuler         262             zag
# ..        ...             ...         ...             ...
# 687     99891           Chará         282             ata
# 688     99900    Luan Pereira         314             mei
# 689     99903    Lucas Campos         263             ata
# 690     99915        Ezequiel         283             ata
# 691     99918         Patrick         284             mei
#
# [692 rows x 4 columns]

# %%
jogadores_posicoes = jogadores_2019_ano.join(posicoes_df, jogadores_2019_ano.player_position == posicoes_df.abbr)
jogadores_posicoes.toPandas()
# Out:
#     player_id player_nickname player_team player_position _c0 Cod  Position  \
# 0      100002         Rickson         263             mei   4   4      Meia
# 1      100065         Lincoln         262             ata   5   5  Atacante
# 2      100084      Igor Gomes         276             mei   4   4      Meia
# 3      100103        Pedrinho         293             ata   5   5  Atacante
# 4      100125          Thuler         262             zag   3   3  Zagueiro
# ..        ...             ...         ...             ...  ..  ..       ...
# 687     99891           Chará         282             ata   5   5  Atacante
# 688     99900    Luan Pereira         314             mei   4   4      Meia
# 689     99903    Lucas Campos         263             ata   5   5  Atacante
# 690     99915        Ezequiel         283             ata   5   5  Atacante
# 691     99918         Patrick         284             mei   4   4      Meia
#
#     abbr
# 0    mei
# 1    ata
# 2    mei
# 3    ata
# 4    zag
# ..   ...
# 687  ata
# 688  mei
# 689  ata
# 690  ata
# 691  mei
#
# [692 rows x 8 columns]

# %%
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('player_id', 'ID')
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('player_nickname', 'Apelido')
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('player_team', 'ClubeID')
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('Cod', 'PosicaoID')

# %%
# Removendo colunas
jogadores = jogadores_posicoes.drop('_c0', 'player_position', 'Position', 'abbr')

# %%
jogadores.toPandas()
# Out:
#          ID       Apelido ClubeID PosicaoID
# 0    100002       Rickson     263         4
# 1    100065       Lincoln     262         5
# 2    100084    Igor Gomes     276         4
# 3    100103      Pedrinho     293         5
# 4    100125        Thuler     262         3
# ..      ...           ...     ...       ...
# 687   99891         Chará     282         5
# 688   99900  Luan Pereira     314         4
# 689   99903  Lucas Campos     263         5
# 690   99915      Ezequiel     283         5
# 691   99918       Patrick     284         4
#
# [692 rows x 4 columns]

# %%
jogadores_2019_ano = jogadores.withColumn('year', lit(2019))
jogadores_2019_ano.toPandas()
# Out:
#          ID       Apelido ClubeID PosicaoID  year
# 0    100002       Rickson     263         4  2019
# 1    100065       Lincoln     262         5  2019
# 2    100084    Igor Gomes     276         4  2019
# 3    100103      Pedrinho     293         5  2019
# 4    100125        Thuler     262         3  2019
# ..      ...           ...     ...       ...   ...
# 687   99891         Chará     282         5  2019
# 688   99900  Luan Pereira     314         4  2019
# 689   99903  Lucas Campos     263         5  2019
# 690   99915      Ezequiel     283         5  2019
# 691   99918       Patrick     284         4  2019
#
# [692 rows x 5 columns]

# %%
jogadores_2019_ano.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/jogadores/')

# %%
#transforma arquivo em parquet
jogadores_2019_parquet = spark.read.option('basePath', '/cartola/clean/jogadores/').parquet('/cartola/clean/jogadores/*')

# %%
jogadores_2019_parquet.toPandas()
# Out:
#          ID          Apelido ClubeID PosicaoID  year
# 0     51683     Bruno Rangel     315         5  2014
# 1     51705    Bruno Rodrigo     283         3  2014
# 2     51772  Éverton Ribeiro     283         4  2014
# 3     51779    Pedro Botelho     282         2  2014
# 4     51781            Ávine     265         2  2014
# ...     ...              ...     ...       ...   ...
# 4924  85930            Aylon     327         5  2018
# 4925  51792             Kanu     287         3  2018
# 4926  52190             Ralf     264         4  2018
# 4927  91607             Rony     293         5  2018
# 4928  91639             Igor     217         2  2018
#
# [4929 rows x 5 columns]

# %%
print(jogadores_2019_parquet.count())
# Out:
# 4929

# %% [markdown]
# ## Partidas

# %%
#Carrega arquivo CSV
partidas_2019_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2019/2019_partidas.csv", header=True)

# %%
partidas_2019_df.show(5)
# Out:
# +----------+---------+---------+----------+----------+-----+
# |      date|home_team|away_team|home_score|away_score|round|
# +----------+---------+---------+----------+----------+-----+
# |2019-04-27|      282|      314|         2|         1|    1|
# |2019-04-27|      315|      285|         2|         0|    1|
# |2019-04-27|      262|      283|         3|         1|    1|
# |2019-04-27|      276|      263|         2|         0|    1|
# |2019-04-28|      293|      267|         4|         1|    1|
# +----------+---------+---------+----------+----------+-----+
# only showing top 5 rows

# %%
# Criar nome do time com a string antes do Hífen
partidas_2019_ct = partidas_2019_df.withColumn('away_team', remove_hiphen_udf(partidas_2019_df['away_team']))

partidas_2019_ct = partidas_2019_ct.withColumn('home_score', partidas_2019_ct['home_score'].cast(IntegerType()))

partidas_2019_ct = partidas_2019_ct.withColumn('away_score', partidas_2019_ct['away_score'].cast(IntegerType()))

partidas_2019_ct = partidas_2019_ct.withColumn('total_gols', partidas_2019_ct['away_score'] + partidas_2019_ct['home_score'] )

partidas_2019_ct = partidas_2019_ct.withColumn('year', lit(2019))

time_ganhador = expr(
    """IF(home_score > away_score, home_team, IF(home_score = away_score, 'empate', away_team))"""
)

partidas_2019_ct = partidas_2019_ct.withColumn('result', time_ganhador)

partidas_2019_ct.toPandas()
# Out:
#            date home_team away_team  home_score  away_score round  total_gols  \
# 0    2019-04-27       282       314           2           1     1           3
# 1    2019-04-27       315       285           2           0     1           2
# 2    2019-04-27       262       283           3           1     1           4
# 3    2019-04-27       276       263           2           0     1           2
# 4    2019-04-28       293       267           4           1     1           5
# ..          ...       ...       ...         ...         ...   ...         ...
# 375  2019-12-08       290       284           3           2    38           5
# 376  2019-12-08       285       282           2           1    38           3
# 377  2019-12-08       283       275           0           2    38           2
# 378  2019-12-08       277       262           4           0    38           4
# 379  2019-12-08       341       276           1           2    38           3
#
#      year result
# 0    2019    282
# 1    2019    315
# 2    2019    262
# 3    2019    276
# 4    2019    293
# ..    ...    ...
# 375  2019    290
# 376  2019    285
# 377  2019    275
# 378  2019    277
# 379  2019    276
#
# [380 rows x 9 columns]

# %%
partidas_2019_ct.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/partidas/')

# %%
#transforma arquivo em parquet
partidas_2019_parquet = spark.read.option('basePath', '/cartola/clean/partidas/').parquet('/cartola/clean/partidas/*')

# %%
partidas_2019_parquet.toPandas()
# Out:
#       game round                date      home_team  score    away_team  \
# 0        1     1  20/04/2014 - 18:30       flamengo  0 x 0        goiás
# 1        2     1  19/04/2014 - 18:30     fluminense  3 x 0  figueirense
# 2        3     1  20/04/2014 - 16:00      são paulo  3 x 0     botafogo
# 3        4     1  20/04/2014 - 18:30         santos  1 x 1        sport
# 4        5     1  20/04/2014 - 16:00  atletico - pr  1 x 0       grêmio
# ...    ...   ...                 ...            ...    ...          ...
# 2275  None    38          2019-12-08            290   None          284
# 2276  None    38          2019-12-08            285   None          282
# 2277  None    38          2019-12-08            283   None          275
# 2278  None    38          2019-12-08            277   None          262
# 2279  None    38          2019-12-08            341   None          276
#
#                                        arena  home_score  away_score  \
# 0             Mané Garrincha - Brasilia - DF         0.0         0.0
# 1             Maracanã - Rio de Janeiro - RJ         3.0         0.0
# 2                   Morumbi - Sao Paulo - SP         3.0         0.0
# 3                 Vila Belmiro - Santos - SP         1.0         1.0
# 4     Orlando Scarpelli - Florianopolis - SC         1.0         0.0
# ...                                      ...         ...         ...
# 2275                                    None         3.0         2.0
# 2276                                    None         2.0         1.0
# 2277                                    None         0.0         2.0
# 2278                                    None         4.0         0.0
# 2279                                    None         1.0         2.0
#
#       total_gols         result  year
# 0            0.0         empate  2014
# 1            3.0     fluminense  2014
# 2            3.0      são paulo  2014
# 3            2.0         empate  2014
# 4            1.0  atletico - pr  2014
# ...          ...            ...   ...
# 2275         5.0            290  2019
# 2276         3.0            285  2019
# 2277         2.0            275  2019
# 2278         4.0            277  2019
# 2279         3.0            276  2019
#
# [2280 rows x 12 columns]

# %% [markdown]
# ## Times

# %%
times_2019_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2019/rodada-1.csv", header=True)

times_2019_df.schema
# Out:
# StructType(List(StructField(_c0,StringType,true),StructField(atletas.nome,StringType,true),StructField(atletas.slug,StringType,true),StructField(atletas.apelido,StringType,true),StructField(atletas.foto,StringType,true),StructField(atletas.atleta_id,StringType,true),StructField(atletas.rodada_id,StringType,true),StructField(atletas.clube_id,StringType,true),StructField(atletas.posicao_id,StringType,true),StructField(atletas.status_id,StringType,true),StructField(atletas.pontos_num,StringType,true),StructField(atletas.preco_num,StringType,true),StructField(atletas.variacao_num,StringType,true),StructField(atletas.media_num,StringType,true),StructField(atletas.clube.id.full.name,StringType,true),StructField(FS,StringType,true),StructField(RB,StringType,true),StructField(PE,StringType,true),StructField(FC,StringType,true),StructField(G,StringType,true),StructField(FF,StringType,true),StructField(FT,StringType,true),StructField(FD,StringType,true),StructField(DD,StringType,true),StructField(GS,StringType,true),StructField(SG,StringType,true),StructField(A,StringType,true),StructField(CA,StringType,true),StructField(I,StringType,true),StructField(CV,StringType,true),StructField(PP,StringType,true),StructField(GC,StringType,true),StructField(DP,StringType,true)))

# %%
times_2019_df = times_2019_df.withColumnRenamed('atletas.clube_id', 'Abreviacao')
times_2019_df = times_2019_df.withColumnRenamed('atletas.clube.id.full.name', 'Nome')

# %%
times_2019_df = times_2019_df['Abreviacao', 'Nome']
times_2019_df = times_2019_df.dropDuplicates(['Abreviacao', 'Nome'])
times_2019_df.toPandas()
# Out:
#    Abreviacao           Nome
# 0         354          Ceará
# 1         314           Avaí
# 2         315    Chapecoense
# 3         284         Grêmio
# 4         283       Cruzeiro
# 5         277         Santos
# 6         276      São Paulo
# 7         282    Atlético-MG
# 8         267          Vasco
# 9         262       Flamengo
# 10        285  Internacional
# 11        263       Botafogo
# 12        266     Fluminense
# 13        290          Goiás
# 14        356      Fortaleza
# 15        265          Bahia
# 16        341            CSA
# 17        293   Athlético-PR
# 18        264    Corinthians

# %%
#Ler tabela de referencia Times_ids
times_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/times_ids.csv", header=True)
times_df = times_df.withColumnRenamed('abreviacao', 'abbr')
times_df.limit(5).toPandas()
# Out:
#         nome.cbf nome.cartola        nome.completo cod.older cod.2017  \
# 0   América - MG   América-MG           America MG       327      327
# 1   America - RN  Atlético-RN           America RN       200      200
# 2  Atlético - GO  Atlético-GO          Atletico GO       201      373
# 3  Atlético - MG  Atlético-MG     Atletico Mineiro       282      282
# 4  Atlético - PR  Atlético-PR  Atletico Paranaense       293      293
#
#   cod.2018   id abbr                                      escudos.60x60  \
# 0      327  327  AME  https://s.glbimg.com/es/sde/f/organizacoes/201...
# 1        1  200  OUT                                               None
# 2      373  373  ATL                                               None
# 3      282  282  ATL  https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 4      293  293  ATL  https://s.glbimg.com/es/sde/f/equipes/2015/06/...
#
#                                        escudos.45x45  \
# 0  https://s.glbimg.com/es/sde/f/organizacoes/201...
# 1                                               None
# 2                                               None
# 3  https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 4  https://s.glbimg.com/es/sde/f/equipes/2015/06/...
#
#                                        escudos.30x30
# 0  https://s.glbimg.com/es/sde/f/organizacoes/201...
# 1                                               None
# 2                                               None
# 3  https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 4  https://s.glbimg.com/es/sde/f/equipes/2015/06/...

# %%
times_df = times_df.withColumnRenamed('nome.cartola', 'ncartola')

# %%
times = times_2019_df.join(times_df, times_2019_df.Nome == times_df.ncartola)

times.toPandas()
# Out:
#    Abreviacao           Nome            nome.cbf       ncartola  \
# 0         354          Ceará          Ceará - CE          Ceará
# 1         314           Avaí           Avaí - SC           Avaí
# 2         315    Chapecoense    Chapecoense - SC    Chapecoense
# 3         284         Grêmio         Grêmio - RS         Grêmio
# 4         283       Cruzeiro       Cruzeiro - MG       Cruzeiro
# 5         277         Santos         Santos - SP         Santos
# 6         276      São Paulo      São Paulo - SP      São Paulo
# 7         282    Atlético-MG       Atlético - MG    Atlético-MG
# 8         267          Vasco  Vasco da Gama - RJ          Vasco
# 9         262       Flamengo       Flamengo - RJ       Flamengo
# 10        285  Internacional  Internacional - RS  Internacional
# 11        263       Botafogo       Botafogo - RJ       Botafogo
# 12        266     Fluminense     Fluminense - RJ     Fluminense
# 13        290          Goiás          Goiás - GO          Goiás
# 14        356      Fortaleza           Fortaleza      Fortaleza
# 15        265          Bahia          Bahia - BA          Bahia
# 16        341            CSA                 CSA            CSA
# 17        293   Athlético-PR        Athlético-PR   Athlético-PR
# 18        264    Corinthians    Corinthians - SP    Corinthians
#
#           nome.completo cod.older cod.2017 cod.2018   id abbr  \
# 0              Ceara SC       204      204      354  354  CEA
# 1               Avai FC       202      314      314  314  AVA
# 2           Chapecoense       315      315      315  315  CHA
# 3   Gremio Porto Alegre       284      284      284  284  GRE
# 4           Cruzeiro EC       283      283      283  283  CRU
# 5             Santos FC       277      277      277  277  SAN
# 6          Sao Paulo FC       276      276      276  276  SAO
# 7      Atletico Mineiro       282      282      282  282  ATL
# 8         Vasco da Gama       221      267      267  267  VAS
# 9           Flamengo RJ       262      262      262  262  FLA
# 10        Internacional       285      285      285  285  INT
# 11          Botafogo RJ       263      263      263  263  BOT
# 12        Fluminense RJ       266      266      266  266  FLU
# 13             Goias EC       210      210      290  290  GOI
# 14            Fortaleza       209      209      356  356  FOR
# 15             EC Bahia       207      265      265  265  BAH
# 16                  CSA       341      341      341  341  CSA
# 17  Atletico Paranaense       293      293      293  293  ATL
# 18       Corinthians SP       264      264      264  264  COR
#
#                                         escudos.60x60  \
# 0   https://s.glbimg.com/es/sde/f/equipes/2018/05/...
# 1                                                None
# 2   https://s.glbimg.com/es/sde/f/equipes/2015/08/...
# 3   https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 4   https://s.glbimg.com/es/sde/f/equipes/2015/04/...
# 5   https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 6   https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 7   https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 8   https://s.glbimg.com/es/sde/f/equipes/2016/07/...
# 9   https://s.glbimg.com/es/sde/f/equipes/2018/04/...
# 10  https://s.glbimg.com/es/sde/f/equipes/2016/05/...
# 11  https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 12  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 13                                               None
# 14                                               None
# 15  https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 16                                               None
# 17                                               None
# 18  https://s.glbimg.com/es/sde/f/equipes/2014/04/...
#
#                                         escudos.45x45  \
# 0   https://s.glbimg.com/es/sde/f/equipes/2018/05/...
# 1                                                None
# 2   https://s.glbimg.com/es/sde/f/equipes/2015/08/...
# 3   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 4   https://s.glbimg.com/es/sde/f/equipes/2015/04/...
# 5   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 6   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 7   https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 8   https://s.glbimg.com/es/sde/f/equipes/2016/07/...
# 9   https://s.glbimg.com/es/sde/f/equipes/2018/04/...
# 10  https://s.glbimg.com/es/sde/f/equipes/2016/05/...
# 11  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 12  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 13                                               None
# 14                                               None
# 15  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 16                                               None
# 17                                               None
# 18  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
#
#                                         escudos.30x30
# 0   https://s.glbimg.com/es/sde/f/equipes/2018/05/...
# 1                                                None
# 2   https://s.glbimg.com/es/sde/f/equipes/2015/08/...
# 3   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 4   https://s.glbimg.com/es/sde/f/equipes/2015/04/...
# 5   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 6   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 7   https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 8   https://s.glbimg.com/es/sde/f/equipes/2016/07/...
# 9   https://s.glbimg.com/es/sde/f/equipes/2018/04/...
# 10  https://s.glbimg.com/es/sde/f/equipes/2016/05/...
# 11  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 12  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 13                                               None
# 14                                               None
# 15  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 16                                               None
# 17                                               None
# 18  https://s.glbimg.com/es/sde/f/equipes/2013/12/...

# %%
times = times['Abreviacao', 'Nome', 'id']
times.toPandas()
# Out:
#    Abreviacao           Nome   id
# 0         354          Ceará  354
# 1         314           Avaí  314
# 2         315    Chapecoense  315
# 3         284         Grêmio  284
# 4         283       Cruzeiro  283
# 5         277         Santos  277
# 6         276      São Paulo  276
# 7         282    Atlético-MG  282
# 8         267          Vasco  267
# 9         262       Flamengo  262
# 10        285  Internacional  285
# 11        263       Botafogo  263
# 12        266     Fluminense  266
# 13        290          Goiás  290
# 14        356      Fortaleza  356
# 15        265          Bahia  265
# 16        341            CSA  341
# 17        293   Athlético-PR  293
# 18        264    Corinthians  264

# %%
times_2019_df = times.dropDuplicates(['Abreviacao', 'Nome', 'id'])

# %%
times_2019_df = times_2019_df.withColumnRenamed('id', 'ID')
times_2019_df.toPandas()
# Out:
#    Abreviacao           Nome
# 0         354          Ceará
# 1         314           Avaí
# 2         315    Chapecoense
# 3         284         Grêmio
# 4         283       Cruzeiro
# 5         277         Santos
# 6         276      São Paulo
# 7         282    Atlético-MG
# 8         267          Vasco
# 9         262       Flamengo
# 10        285  Internacional
# 11        263       Botafogo
# 12        266     Fluminense
# 13        290          Goiás
# 14        356      Fortaleza
# 15        265          Bahia
# 16        341            CSA
# 17        293   Athlético-PR
# 18        264    Corinthians

# %%
#Adiciona coluna ANO = 2019
times_2019_df = times_2019_df.withColumn('year', lit(2019))
times_2019_df.toPandas()
# Out:
#    Abreviacao           Nome  year
# 0         354          Ceará  2019
# 1         314           Avaí  2019
# 2         315    Chapecoense  2019
# 3         284         Grêmio  2019
# 4         283       Cruzeiro  2019
# 5         277         Santos  2019
# 6         276      São Paulo  2019
# 7         282    Atlético-MG  2019
# 8         267          Vasco  2019
# 9         262       Flamengo  2019
# 10        285  Internacional  2019
# 11        263       Botafogo  2019
# 12        266     Fluminense  2019
# 13        290          Goiás  2019
# 14        356      Fortaleza  2019
# 15        265          Bahia  2019
# 16        341            CSA  2019
# 17        293   Athlético-PR  2019
# 18        264    Corinthians  2019

# %%
times_2019_df.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/times/')
#transforma arquivo em parquet
times_2019_parquet = spark.read.option('basePath', '/cartola/clean/times/').parquet('/cartola/clean/times/*')

# %%
times_2019_parquet.toPandas()
# Out:
#        ID         Nome Abreviacao           Slug  year
# 0     373  Atlético-GO        ATL  Atlético - GO  2017
# 1     282  Atlético-MG        ATL  Atlético - MG  2017
# 2     293  Atlético-PR        ATL  Atlético - PR  2017
# 3     314         Avaí        AVA      Avaí - SC  2017
# 4     265        Bahia        BAH     Bahia - BA  2017
# ..    ...          ...        ...            ...   ...
# 114  None     Botafogo        263           None  2019
# 115  None         Avaí        314           None  2019
# 116  None        Vasco        267           None  2019
# 117  None        Bahia        265           None  2019
# 118  None          CSA        341           None  2019
#
# [119 rows x 5 columns]

# %% [markdown]
# ## scouts_raw

# %%
# Analisando o arquivo 2014_lances.csv vimos que não é necessário processar esse arquivo, pois as informações relevantes estão em scouts_raw.

# %%
scouts_raw_2019_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2019/rodada-*.csv", header=True)

# %%
scouts_raw_2019_ano = scouts_raw_2019_df.withColumn('year', lit(2019))

# %%
scouts_raw_2019_ano.schema
# Out:
# StructType(List(StructField(_c0,StringType,true),StructField(atletas.nome,StringType,true),StructField(atletas.slug,StringType,true),StructField(atletas.apelido,StringType,true),StructField(atletas.foto,StringType,true),StructField(atletas.atleta_id,StringType,true),StructField(atletas.rodada_id,StringType,true),StructField(atletas.clube_id,StringType,true),StructField(atletas.posicao_id,StringType,true),StructField(atletas.status_id,StringType,true),StructField(atletas.pontos_num,StringType,true),StructField(atletas.preco_num,StringType,true),StructField(atletas.variacao_num,StringType,true),StructField(atletas.media_num,StringType,true),StructField(atletas.clube.id.full.name,StringType,true),StructField(CA,StringType,true),StructField(CV,StringType,true),StructField(FC,StringType,true),StructField(FD,StringType,true),StructField(FF,StringType,true),StructField(FS,StringType,true),StructField(PE,StringType,true),StructField(RB,StringType,true),StructField(SG,StringType,true),StructField(DD,StringType,true),StructField(DP,StringType,true),StructField(GS,StringType,true),StructField(A,StringType,true),StructField(G,StringType,true),StructField(I,StringType,true),StructField(PP,StringType,true),StructField(FT,StringType,true),StructField(GC,StringType,true),StructField(year,IntegerType,false)))

# %%
scouts_raw_2019_ano.toPandas()
# Out:
#        _c0                         atletas.nome  atletas.slug atletas.apelido  \
# 0        1                Ebert William Amâncio         betao           Betão
# 1        2        Ney Franco da Silveira Júnior    ney-franco      Ney Franco
# 2        3           Fábio Deivson Lopes Maciel         fabio           Fábio
# 3        4   Rafael Martiniano de Miranda Moura  rafael-moura    Rafael Moura
# 4        5       Eduardo Luís Abonizio de Souza   edu-dracena     Edu Dracena
# ...    ...                                  ...           ...             ...
# 30576  734          Nilson Evair Loyola Morales        loyola          Loyola
# 30577  735      Thalles Gabriel Morais dos Reis       thalles         Thalles
# 30578  736       Marcio Antonio de Sousa Júnior      marcinho        Marcinho
# 30579  737          Hélio Júnio Nunes de Castro       helinho         Helinho
# 30580  738  Michael Richard Delgado de Oliveira       michael         Michael
#
#                                             atletas.foto atletas.atleta_id  \
# 0      https://s.glbimg.com/es/sde/f/2019/02/18/c0b80...             37646
# 1      https://s.glbimg.com/es/sde/f/2019/08/16/4fdb0...             37246
# 2      https://s.glbimg.com/es/sde/f/2018/05/18/d4072...             37656
# 3      https://s.glbimg.com/es/sde/f/2019/07/16/854eb...             37655
# 4      https://s.glbimg.com/es/sde/f/2019/06/05/4b2eb...             37657
# ...                                                  ...               ...
# 30576  https://s.glbimg.com/es/sde/f/2019/03/26/c4579...             94680
# 30577  https://s.glbimg.com/es/sde/f/2019/03/26/56b3e...             95222
# 30578  https://s.glbimg.com/es/sde/f/2019/03/26/dd575...             95332
# 30579  https://s.glbimg.com/es/sde/f/2019/04/01/a4da3...            102598
# 30580  https://s.glbimg.com/es/sde/f/2019/03/26/57b50...             99392
#
#       atletas.rodada_id atletas.clube_id atletas.posicao_id atletas.status_id  \
# 0                    38              314                zag        Contundido
# 1                    38              290                tec          Provável
# 2                    38              283                gol          Provável
# 3                    38              290                ata          Provável
# 4                    38              275                zag            Dúvida
# ...                 ...              ...                ...               ...
# 30576                 2              290                lat              Nulo
# 30577                 2              290                mei              Nulo
# 30578                 2              290                mei              Nulo
# 30579                 2              276                ata              Nulo
# 30580                 2              290                ata              Nulo
#
#        ...  DD  DP  GS   A   G   I  PP  FT  GC  year
# 0      ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 1      ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 2      ...  44   2  40  NA  NA  NA  NA  NA  NA  2019
# 3      ...  NA  NA  NA   1   9   7  NA  NA  NA  2019
# 4      ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# ...    ...  ..  ..  ..  ..  ..  ..  ..  ..  ..   ...
# 30576  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30577  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30578  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30579  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30580  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
#
# [30581 rows x 34 columns]

# %%
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.atleta_id', 'AtletaID')
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.clube_id', 'ClubeID')
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.pontos_num', 'Pontos')
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.preco_num', 'Preco')
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.variacao_num', 'PrecoVariacao')
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.preco_num', 'Preco')

# %%
scouts_raw_2019_ano = scouts_raw_2019_ano.drop('scout', 'atletas.apelido', 'atletas.clube.id.full.name', 'atletas.foto', 'atletas.jogos_num', 'atletas.nome', 'atletas.posicao_id', 'atletas.status_id',  )

# %%
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumn("Pontos", scouts_raw_2019_ano["Pontos"].cast(FloatType()))

# %%
scouts_raw_2019_ano.toPandas()
# Out:
#        _c0  atletas.slug AtletaID atletas.rodada_id ClubeID     Pontos  Preco  \
# 0        1         betao    37646                38     314   0.000000   3.97
# 1        2    ney-franco    37246                38     290   6.260000  10.17
# 2        3         fabio    37656                38     283   2.000000  10.35
# 3        4  rafael-moura    37655                38     290  22.200001   7.86
# 4        5   edu-dracena    37657                38     275   0.000000   5.61
# ...    ...           ...      ...               ...     ...        ...    ...
# 30576  734        loyola    94680                 2     290   0.000000      2
# 30577  735       thalles    95222                 2     290   0.000000      2
# 30578  736      marcinho    95332                 2     290   0.000000   3.05
# 30579  737       helinho   102598                 2     276   0.000000      6
# 30580  738       michael    99392                 2     290   0.500000   2.52
#
#       PrecoVariacao atletas.media_num  CA  ...  DD  DP  GS   A   G   I  PP  \
# 0                 0              1.91   6  ...  NA  NA  NA  NA  NA  NA  NA
# 1              0.59              3.73  NA  ...  NA  NA  NA  NA  NA  NA  NA
# 2              0.42              3.43   2  ...  44   2  40  NA  NA  NA  NA
# 3              2.89              3.34   4  ...  NA  NA  NA   1   9   7  NA
# 4                 0               3.7   1  ...  NA  NA  NA  NA  NA  NA  NA
# ...             ...               ...  ..  ...  ..  ..  ..  ..  ..  ..  ..
# 30576             0                 0  NA  ...  NA  NA  NA  NA  NA  NA  NA
# 30577             0                 0  NA  ...  NA  NA  NA  NA  NA  NA  NA
# 30578             0              -0.6  NA  ...  NA  NA  NA  NA  NA  NA  NA
# 30579             0                 0  NA  ...  NA  NA  NA  NA  NA  NA  NA
# 30580         -1.02              -0.2   1  ...  NA  NA  NA  NA  NA  NA  NA
#
#        FT  GC  year
# 0      NA  NA  2019
# 1      NA  NA  2019
# 2      NA  NA  2019
# 3      NA  NA  2019
# 4      NA  NA  2019
# ...    ..  ..   ...
# 30576  NA  NA  2019
# 30577  NA  NA  2019
# 30578  NA  NA  2019
# 30579  NA  NA  2019
# 30580  NA  NA  2019
#
# [30581 rows x 28 columns]

# %%
scouts_raw_2019_ano.schema
# Out:
# StructType(List(StructField(_c0,StringType,true),StructField(atletas.slug,StringType,true),StructField(AtletaID,StringType,true),StructField(atletas.rodada_id,StringType,true),StructField(ClubeID,StringType,true),StructField(Pontos,FloatType,true),StructField(Preco,StringType,true),StructField(PrecoVariacao,StringType,true),StructField(atletas.media_num,StringType,true),StructField(CA,StringType,true),StructField(CV,StringType,true),StructField(FC,StringType,true),StructField(FD,StringType,true),StructField(FF,StringType,true),StructField(FS,StringType,true),StructField(PE,StringType,true),StructField(RB,StringType,true),StructField(SG,StringType,true),StructField(DD,StringType,true),StructField(DP,StringType,true),StructField(GS,StringType,true),StructField(A,StringType,true),StructField(G,StringType,true),StructField(I,StringType,true),StructField(PP,StringType,true),StructField(FT,StringType,true),StructField(GC,StringType,true),StructField(year,IntegerType,false)))

# %%
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.rodada_id', 'Rodada')
scouts_raw_2019_ano = scouts_raw_2019_ano.withColumnRenamed('atletas.media_num', 'PontosMedia')

# %%
scouts_raw_2019_ano = scouts_raw_2019_ano.drop('_c0', 'atletas.slug')
scouts_raw_2019_ano.toPandas()
# Out:
#       AtletaID Rodada ClubeID     Pontos  Preco PrecoVariacao PontosMedia  CA  \
# 0        37646     38     314   0.000000   3.97             0        1.91   6
# 1        37246     38     290   6.260000  10.17          0.59        3.73  NA
# 2        37656     38     283   2.000000  10.35          0.42        3.43   2
# 3        37655     38     290  22.200001   7.86          2.89        3.34   4
# 4        37657     38     275   0.000000   5.61             0         3.7   1
# ...        ...    ...     ...        ...    ...           ...         ...  ..
# 30576    94680      2     290   0.000000      2             0           0  NA
# 30577    95222      2     290   0.000000      2             0           0  NA
# 30578    95332      2     290   0.000000   3.05             0        -0.6  NA
# 30579   102598      2     276   0.000000      6             0           0  NA
# 30580    99392      2     290   0.500000   2.52         -1.02        -0.2   1
#
#        CV  FC  ...  DD  DP  GS   A   G   I  PP  FT  GC  year
# 0       1  20  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 1      NA  NA  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 2      NA  NA  ...  44   2  40  NA  NA  NA  NA  NA  NA  2019
# 3       1  53  ...  NA  NA  NA   1   9   7  NA  NA  NA  2019
# 4      NA   4  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# ...    ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..   ...
# 30576  NA  NA  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30577  NA  NA  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30578  NA   2  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30579  NA  NA  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
# 30580   2   7  ...  NA  NA  NA  NA  NA  NA  NA  NA  NA  2019
#
# [30581 rows x 26 columns]

# %%
scouts_raw_2019_ano.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/scouts/')
#transforma arquivo em parquet
scouts_raw_2019_ano = spark.read.option('basePath', '/cartola/clean/scouts/').parquet('/cartola/clean/scouts/*')

# %%
scouts_raw_2019_ano.toPandas()
# Out:
#        AtletaID Rodada ClubeID Participou Posicao Jogos  Pontos PontosMedia  \
# 0         36540      0     FLA       None    None  None     0.0        None
# 1         36612      0     PAL       None    None  None     0.0        None
# 2         36943      0     ATL       None    None  None     0.0        None
# 3         37245      0     BAH       None    None  None     0.0        None
# 4         37246      0     SPO       None    None  None     0.0        None
# ...         ...    ...     ...        ...     ...   ...     ...         ...
# 187184    94680      2     290       None    None  None     0.0           0
# 187185    95222      2     290       None    None  None     0.0           0
# 187186    95332      2     290       None    None  None     0.0        -0.6
# 187187   102598      2     276       None    None  None     0.0           0
# 187188    99392      2     290       None    None  None     0.5        -0.2
#
#        Preco PrecoVariacao  ...    RB    FC    GC    CA    CV    SG    DD  \
# 0          5             0  ...  None  None  None  None  None  None  None
# 1          8             0  ...  None  None  None  None  None  None  None
# 2         10             0  ...  None  None  None  None  None  None  None
# 3          4             0  ...  None  None  None  None  None  None  None
# 4          4             0  ...  None  None  None  None  None  None  None
# ...      ...           ...  ...   ...   ...   ...   ...   ...   ...   ...
# 187184     2             0  ...    NA    NA    NA    NA    NA    NA    NA
# 187185     2             0  ...    NA    NA    NA    NA    NA    NA    NA
# 187186  3.05             0  ...    NA     2    NA    NA    NA    NA    NA
# 187187     6             0  ...    NA    NA    NA    NA    NA    NA    NA
# 187188  2.52         -1.02  ...    NA     7    NA     1     2    NA    NA
#
#           DP    GS  year
# 0       None  None  2017
# 1       None  None  2017
# 2       None  None  2017
# 3       None  None  2017
# 4       None  None  2017
# ...      ...   ...   ...
# 187184    NA    NA  2019
# 187185    NA    NA  2019
# 187186    NA    NA  2019
# 187187    NA    NA  2019
# 187188    NA    NA  2019
#
# [187189 rows x 35 columns]

# %%
# -        Quantas partidas resultaram em empate?
pontos_por_atleta = scouts_raw_2019_ano[scouts_raw_2019_ano['year'] == 2019]

jogadores_2019 = jogadores_2019_parquet[jogadores_2019_parquet['year'] == 2019]

pontos_por_atleta = pontos_por_atleta.groupBy("AtletaID").agg(sum("Pontos").alias("SomaPontos"))

#count_result = count_result.withColumn('total_wins', count_result['count(1)'])

pontos_por_atleta = pontos_por_atleta.sort(pontos_por_atleta.SomaPontos.desc())

#count_result = count_result.drop('count(1)')

#count_result.show(5)


pontos_por_atleta.toPandas()
# Out:
#      AtletaID  SomaPontos
# 0       83257  269.300001
# 1       90285  244.900002
# 2       82453  233.600001
# 3       87863  229.100004
# 4       81677  214.100001
# ...       ...         ...
# 1006   102598   -3.400000
# 1007    63082   -4.000000
# 1008    50294   -4.200000
# 1009    99462   -5.100000
# 1010    62129  -20.999999
#
# [1011 rows x 2 columns]

# %%
scouts_atletas = pontos_por_atleta.join(jogadores_2019, pontos_por_atleta.AtletaID == jogadores_2019.ID)
scouts_atletas = scouts_atletas.sort(scouts_atletas.SomaPontos.desc())
scouts_atletas.toPandas()
# Out:
#     AtletaID  SomaPontos      ID         Apelido ClubeID PosicaoID  year
# 0      83257  269.300001   83257         Gabriel     262         5  2019
# 1      90285  244.900002   90285  Bruno Henrique     262         5  2019
# 2      82453  233.600001   82453           Tadeu     290         1  2019
# 3      87863  229.100004   87863      Arrascaeta     262         4  2019
# 4      81677  214.100001   81677  Carlos Sánchez     277         4  2019
# ..       ...         ...     ...             ...     ...       ...   ...
# 687   102598   -3.400000  102598         Helinho     276         5  2019
# 688    63082   -4.000000   63082         Rodolfo     266         1  2019
# 689    50294   -4.200000   50294       Guilherme     266         4  2019
# 690    99462   -5.100000   99462          Wesley     314         4  2019
# 691    62129  -20.999999   62129      Wellington     293         4  2019
#
# [692 rows x 7 columns]

# %% [markdown]
# ## DEMONSTRAÇÃO

# %%
partidas_2014_df = spark.read.csv("/cartola/data/2014/2014_jogadores.csv", header=True)
partidas_2014_ct = partidas_2014_df.withColumn('time', regexp_replace('home_team', ' - RJ', ''))
final_partidas = partidas_2014_ct.withColumn('time_low', lower(col('time'))).show(truncate=False)

# %%
with_ano_partidas = partidas_2014_ct.withColumn('ano', lit(2014)).show(truncate=False)
with_ano_partidas.show()

# %%
Comando para sobrescrever arquivo caso já existente.
Agrupar scouts por ID e contar (caso tenha duplicidade)

# %%
inner_join = partidas_ids_2014_ano.join(times_2014_ano, partidas_ids_2014_ano.Casa == times_2014_ano.ID)
inner_join.toPandas()
# Out:
#          ID Rodada Casa Visitante PlacarCasa PlacarVisitante  Resultado   ano  \
# 0    179872      1  262       290          0               0     Empate  2014
# 1    179873      1  266       316          3               0       Casa  2014
# 2    179874      1  276       263          3               0       Casa  2014
# 3    179875      1  277       292          1               1     Empate  2014
# 4    179876      1  293       284          1               0       Casa  2014
# ..      ...    ...  ...       ...        ...             ...        ...   ...
# 375  180250     29  282       315          1               0       Casa  2014
# 376  180251     29  287       283          0               1  Visitante  2014
# 377  180252     29  285       264          1               2  Visitante  2014
# 378  180253     29  316       294          4               0       Casa  2014
# 379  180254     29  290       284          0               0     Empate  2014
#
#       ID           Nome Abreviacao           Slug   ano
# 0    262       flamengo        FLA       flamengo  2014
# 1    266     fluminense        FLU     fluminense  2014
# 2    276      são paulo        SAO      sao-paulo  2014
# 3    277         santos        SAN         santos  2014
# 4    293    atlético-pr        CAP    atletico-pr  2014
# ..   ...            ...        ...            ...   ...
# 375  282    atlético-mg        CAM    atletico-mg  2014
# 376  287        vitória        VIT        vitoria  2014
# 377  285  internacional        INT  internacional  2014
# 378  316    figueirense        FIG    figueirense  2014
# 379  290          goiás        GOI          goias  2014
#
# [380 rows x 13 columns]

# %%
scouts_atletas = pontos_por_atleta.join(jogadores_2014_parquet, pontos_por_atleta.Atleta == jogadores_2014_parquet.ID)
scouts_atletas = scouts_atletas.sort(scouts_atletas.SomaPontos.desc())
scouts_atletas.toPandas()

# %%
# -        Quantas partidas resultaram em empate?
pontos_por_atleta = scouts_raw_2014_ano.groupBy("Atleta").agg(sum("Pontos").alias("SomaPontos"))

#count_result = count_result.withColumn('total_wins', count_result['count(1)'])

pontos_por_atleta = pontos_por_atleta.sort(pontos_por_atleta.SomaPontos.desc())

#count_result = count_result.drop('count(1)')

#count_result.show(5)


pontos_por_atleta.toPandas()
