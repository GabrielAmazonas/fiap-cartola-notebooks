# %% [markdown]
# ## Limpeza de dados Cartola ano 2020

# %%
from pyspark.sql import HiveContext
from pyspark.sql.types import IntegerType, StringType, FloatType
from pyspark.sql.functions import lower, col, lit, regexp_replace, trim, substring, when, expr, udf, count, sum, monotonically_increasing_id
import pandas as pd
import json
import requests

# Confirguração para não sobrescrever DF
spark.conf.set('spark.sql.sources.partitionOverwriteMode', 'dynamic')

# %% [markdown]
# ## Funções Customizadas

# %%
def remove_after_hiphen(team_name):
    if team_name.startswith('atletico') or team_name.startswith('atl')  or team_name.startswith('Atl') or team_name.startswith('Ath'):
        return team_name
    else:
        return team_name.split('-', 1)[0]

# %%
#Remove dos valores das Strings o que estiver após os hiphen
remove_hiphen_udf = udf(remove_after_hiphen, StringType())
#partidas_2014_ct = partidas_2014_df.withColumn('away_team', remove_hiphen_udf(partidas_2014_df['away_team']))

# %% [markdown]
# ## Jogadores

# %%
#Carrega arquivo CSV Jogadores
jogadores_2020_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2020/2020-medias-jogadores.csv", header=True)
sorted_jogadores_2020_df = jogadores_2020_df.sort(jogadores_2020_df.player_id.asc())

# %%
#Carrega arquivo Posicoes_ID
posicoes_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/posicoes_ids.csv", header=True)
posicoes_df.toPandas()
# Out:
#   _c0 Cod  Position abbr
# 0   1   1   Goleiro  gol
# 1   2   2   Lateral  lat
# 2   3   3  Zagueiro  zag
# 3   4   4      Meia  mei
# 4   5   5  Atacante  ata
# 5   6   6   Técnico  tec

# %%
#Adiciona coluna ANO = 2020
jogadores_2020_ano = sorted_jogadores_2020_df.withColumn('year', lit(2020))
jogadores_2020_ano.toPandas()
# Out:
#       player_slug player_id player_nickname player_team player_position  \
# 0         lincoln    100065         Lincoln         262             ata
# 1      igor-gomes    100084      Igor Gomes         276             mei
# 2        pedrinho    100103        Pedrinho         293             ata
# 3          thuler    100125          Thuler         262             zag
# 4    lucas-venuto    100290    Lucas Venuto         292             ata
# ..            ...       ...             ...         ...             ...
# 594       michael     99392         Michael         262             ata
# 595      fernando     99550        Fernando         263             lat
# 596       brenner     99789         Brenner         276             ata
# 597       ricardo     99881         Ricardo         267             zag
# 598       patrick     99918         Patrick         284             mei
#
#     price_cartoletas          score_mean score_no_cleansheets_mean  \
# 0               4.25                 1.4                       1.4
# 1               3.04   0.792857142857143         0.792857142857143
# 2               2.25               0.725                     0.725
# 3               2.12  0.0666666666666666        0.0666666666666666
# 4               2.16    1.28333333333333          1.28333333333333
# ..               ...                 ...                       ...
# 594             5.43               1.825                     1.825
# 595              3.2                   1                         1
# 596             5.05                5.62                      5.62
# 597             7.13                 3.7                       1.2
# 598             2.74                -0.5                      -0.5
#
#     diff_home_away_s n_games  ...              A_mean I_mean  \
# 0                  0       8  ...                   0      0
# 1                  0      14  ...  0.0714285714285714      0
# 2                  0       8  ...                   0      0
# 3                  0       3  ...                   0      0
# 4                  0       6  ...                   0      0
# ..               ...     ...  ...                 ...    ...
# 594                0       8  ...               0.125      0
# 595                0       2  ...                   0      0
# 596                0      10  ...                 0.1    0.4
# 597                0       8  ...                   0      0
# 598                0       1  ...                   0      0
#
#                FS_mean            FF_mean G_mean DD_mean  status price_diff  \
# 0                    0                  0  0.125       0    Nulo      -0.61
# 1     1.07142857142857  0.285714285714286      0       0    Nulo      -0.67
# 2                  0.5              0.375      0       0    Nulo      -0.15
# 3    0.666666666666667                  0      0       0    Nulo      -0.25
# 4     2.33333333333333                  0      0       0    Nulo      -0.04
# ..                 ...                ...    ...     ...     ...        ...
# 594               0.25               1.25      0       0    Nulo      -0.48
# 595                  0                  0      0       0  Dúvida       0.65
# 596                  1                0.9    0.5       0    Nulo      -0.61
# 597                0.5              0.375      0       0  Dúvida      -0.04
# 598                  0                  0      0       0    Nulo      -1.26
#
#     last_points  year
# 0             6  2020
# 1          -1.7  2020
# 2           0.4  2020
# 3          -0.6  2020
# 4           0.4  2020
# ..          ...   ...
# 594        -1.1  2020
# 595         5.3  2020
# 596        -0.8  2020
# 597        -0.1  2020
# 598        -0.5  2020
#
# [599 rows x 26 columns]

# %%
jogadores_2020_ano = jogadores_2020_ano['player_id', 'player_nickname', 'player_team', 'player_position']
jogadores_2020_ano.toPandas()
# Out:
#     player_id player_nickname player_team player_position
# 0      100065         Lincoln         262             ata
# 1      100084      Igor Gomes         276             mei
# 2      100103        Pedrinho         293             ata
# 3      100125          Thuler         262             zag
# 4      100290    Lucas Venuto         292             ata
# ..        ...             ...         ...             ...
# 594     99392         Michael         262             ata
# 595     99550        Fernando         263             lat
# 596     99789         Brenner         276             ata
# 597     99881         Ricardo         267             zag
# 598     99918         Patrick         284             mei
#
# [599 rows x 4 columns]

# %%
jogadores_posicoes = jogadores_2020_ano.join(posicoes_df, jogadores_2020_ano.player_position == posicoes_df.abbr)
jogadores_posicoes.toPandas()
# Out:
#     player_id player_nickname player_team player_position _c0 Cod  Position  \
# 0      100065         Lincoln         262             ata   5   5  Atacante
# 1      100084      Igor Gomes         276             mei   4   4      Meia
# 2      100103        Pedrinho         293             ata   5   5  Atacante
# 3      100125          Thuler         262             zag   3   3  Zagueiro
# 4      100290    Lucas Venuto         292             ata   5   5  Atacante
# ..        ...             ...         ...             ...  ..  ..       ...
# 594     99392         Michael         262             ata   5   5  Atacante
# 595     99550        Fernando         263             lat   2   2   Lateral
# 596     99789         Brenner         276             ata   5   5  Atacante
# 597     99881         Ricardo         267             zag   3   3  Zagueiro
# 598     99918         Patrick         284             mei   4   4      Meia
#
#     abbr
# 0    ata
# 1    mei
# 2    ata
# 3    zag
# 4    ata
# ..   ...
# 594  ata
# 595  lat
# 596  ata
# 597  zag
# 598  mei
#
# [599 rows x 8 columns]

# %%
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('player_id', 'ID')
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('player_nickname', 'Apelido')
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('player_team', 'ClubeID')
jogadores_posicoes = jogadores_posicoes.withColumnRenamed('Cod', 'PosicaoID')

# %%
# Removendo colunas
jogadores = jogadores_posicoes.drop('_c0', 'player_position', 'Position', 'abbr')

# %%
jogadores.toPandas()
# Out:
#          ID       Apelido ClubeID PosicaoID
# 0    100065       Lincoln     262         5
# 1    100084    Igor Gomes     276         4
# 2    100103      Pedrinho     293         5
# 3    100125        Thuler     262         3
# 4    100290  Lucas Venuto     292         5
# ..      ...           ...     ...       ...
# 594   99392       Michael     262         5
# 595   99550      Fernando     263         2
# 596   99789       Brenner     276         5
# 597   99881       Ricardo     267         3
# 598   99918       Patrick     284         4
#
# [599 rows x 4 columns]

# %%
jogadores_2020_ano = jogadores.withColumn('year', lit(2020))
jogadores_2020_ano.toPandas()
# Out:
#          ID       Apelido ClubeID PosicaoID  year
# 0    100065       Lincoln     262         5  2020
# 1    100084    Igor Gomes     276         4  2020
# 2    100103      Pedrinho     293         5  2020
# 3    100125        Thuler     262         3  2020
# 4    100290  Lucas Venuto     292         5  2020
# ..      ...           ...     ...       ...   ...
# 594   99392       Michael     262         5  2020
# 595   99550      Fernando     263         2  2020
# 596   99789       Brenner     276         5  2020
# 597   99881       Ricardo     267         3  2020
# 598   99918       Patrick     284         4  2020
#
# [599 rows x 5 columns]

# %%
jogadores_2020_ano.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/jogadores/')

# %%
#transforma arquivo em parquet
jogadores_2020_parquet = spark.read.option('basePath', '/cartola/clean/jogadores/').parquet('/cartola/clean/jogadores/*')

# %%
jogadores_2020_parquet.toPandas()
# Out:
#          ID          Apelido ClubeID PosicaoID  year
# 0     51683     Bruno Rangel     315         5  2014
# 1     51705    Bruno Rodrigo     283         3  2014
# 2     51772  Éverton Ribeiro     283         4  2014
# 3     51779    Pedro Botelho     282         2  2014
# 4     51781            Ávine     265         2  2014
# ...     ...              ...     ...       ...   ...
# 5523  85930            Aylon     327         5  2018
# 5524  51792             Kanu     287         3  2018
# 5525  52190             Ralf     264         4  2018
# 5526  91607             Rony     293         5  2018
# 5527  91639             Igor     217         2  2018
#
# [5528 rows x 5 columns]

# %%
print(jogadores_2020_parquet.count())
# Out:
# 5528

# %% [markdown]
# ## Partidas

# %%
#Carrega arquivo CSV
partidas_2020_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2020/2020_partidas.csv", header=True)

# %%
partidas_2020_df.show(5)
# Out:
# +----------+---------+---------+----------+----------+-----+
# |      date|home_team|away_team|home_score|away_score|round|
# +----------+---------+---------+----------+----------+-----+
# |2020-08-08|      356|      293|         0|         2|    1|
# |2020-08-08|      294|      285|         0|         1|    1|
# |2020-08-08|      292|      354|         3|         2|    1|
# |2020-08-09|      262|      282|         0|         1|    1|
# |2020-08-09|      277|      280|         1|         1|    1|
# +----------+---------+---------+----------+----------+-----+
# only showing top 5 rows

# %%
# Criar nome do time com a string antes do Hífen
partidas_2020_ct = partidas_2020_df.withColumn('away_team', remove_hiphen_udf(partidas_2020_df['away_team']))

partidas_2020_ct = partidas_2020_ct.withColumn('home_score', partidas_2020_ct['home_score'].cast(IntegerType()))

partidas_2020_ct = partidas_2020_ct.withColumn('away_score', partidas_2020_ct['away_score'].cast(IntegerType()))

partidas_2020_ct = partidas_2020_ct.withColumn('total_gols', partidas_2020_ct['away_score'] + partidas_2020_ct['home_score'] )

partidas_2020_ct = partidas_2020_ct.withColumn('year', lit(2020))

time_ganhador = expr(
    """IF(home_score > away_score, home_team, IF(home_score = away_score, 'empate', away_team))"""
)

partidas_2020_ct = partidas_2020_ct.withColumn('result', time_ganhador)

partidas_2020_ct.toPandas()
# Out:
#            date home_team away_team  home_score  away_score round  total_gols  \
# 0    2020-08-08       356       293           0           2     1           2
# 1    2020-08-08       294       285           0           1     1           1
# 2    2020-08-08       292       354           3           2     1           5
# 3    2020-08-09       262       282           0           1     1           1
# 4    2020-08-09       277       280           1           1     1           2
# ..          ...       ...       ...         ...         ...   ...         ...
# 385  2021-02-25       293       292           2           0    38           2
# 386  2021-02-25       354       263           2           1    38           3
# 387  2021-02-25       354       263           2           1    38           3
# 388  2021-02-25       373       294           3           1    38           4
# 389  2021-02-25       373       294           3           1    38           4
#
#      year  result
# 0    2020     293
# 1    2020     285
# 2    2020     292
# 3    2020     282
# 4    2020  empate
# ..    ...     ...
# 385  2020     293
# 386  2020     354
# 387  2020     354
# 388  2020     373
# 389  2020     373
#
# [390 rows x 9 columns]

# %%
partidas_2020_ct.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/partidas/')

# %%
#transforma arquivo em parquet
partidas_2020_parquet = spark.read.option('basePath', '/cartola/clean/partidas/').parquet('/cartola/clean/partidas/*')

# %%
partidas_2020_parquet.toPandas()
# Out:
#       game round                date      home_team  score    away_team  \
# 0        1     1  20/04/2014 - 18:30       flamengo  0 x 0        goiás
# 1        2     1  19/04/2014 - 18:30     fluminense  3 x 0  figueirense
# 2        3     1  20/04/2014 - 16:00      são paulo  3 x 0     botafogo
# 3        4     1  20/04/2014 - 18:30         santos  1 x 1        sport
# 4        5     1  20/04/2014 - 16:00  atletico - pr  1 x 0       grêmio
# ...    ...   ...                 ...            ...    ...          ...
# 2665  None    38          2019-12-08            290   None          284
# 2666  None    38          2019-12-08            285   None          282
# 2667  None    38          2019-12-08            283   None          275
# 2668  None    38          2019-12-08            277   None          262
# 2669  None    38          2019-12-08            341   None          276
#
#                                        arena  home_score  away_score  \
# 0             Mané Garrincha - Brasilia - DF         0.0         0.0
# 1             Maracanã - Rio de Janeiro - RJ         3.0         0.0
# 2                   Morumbi - Sao Paulo - SP         3.0         0.0
# 3                 Vila Belmiro - Santos - SP         1.0         1.0
# 4     Orlando Scarpelli - Florianopolis - SC         1.0         0.0
# ...                                      ...         ...         ...
# 2665                                    None         3.0         2.0
# 2666                                    None         2.0         1.0
# 2667                                    None         0.0         2.0
# 2668                                    None         4.0         0.0
# 2669                                    None         1.0         2.0
#
#       total_gols         result  year
# 0            0.0         empate  2014
# 1            3.0     fluminense  2014
# 2            3.0      são paulo  2014
# 3            2.0         empate  2014
# 4            1.0  atletico - pr  2014
# ...          ...            ...   ...
# 2665         5.0            290  2019
# 2666         3.0            285  2019
# 2667         2.0            275  2019
# 2668         4.0            277  2019
# 2669         3.0            276  2019
#
# [2670 rows x 12 columns]

# %% [markdown]
# ## Times

# %%
times_2020_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2020/rodada-1.csv", header=True)

times_2020_df.schema
# Out:
# StructType(List(StructField(_c0,StringType,true),StructField(atletas.nome,StringType,true),StructField(atletas.slug,StringType,true),StructField(atletas.apelido,StringType,true),StructField(atletas.foto,StringType,true),StructField(atletas.atleta_id,StringType,true),StructField(atletas.rodada_id,StringType,true),StructField(atletas.clube_id,StringType,true),StructField(atletas.posicao_id,StringType,true),StructField(atletas.status_id,StringType,true),StructField(atletas.pontos_num,StringType,true),StructField(atletas.preco_num,StringType,true),StructField(atletas.variacao_num,StringType,true),StructField(atletas.media_num,StringType,true),StructField(atletas.jogos_num,StringType,true),StructField(atletas.clube.id.full.name,StringType,true),StructField(FF,StringType,true),StructField(FS,StringType,true),StructField(G,StringType,true),StructField(PI,StringType,true),StructField(CA,StringType,true),StructField(FC,StringType,true),StructField(DS,StringType,true),StructField(FT,StringType,true),StructField(DD,StringType,true),StructField(GS,StringType,true),StructField(FD,StringType,true),StructField(GC,StringType,true),StructField(SG,StringType,true),StructField(A,StringType,true),StructField(I,StringType,true),StructField(CV,StringType,true),StructField(PP,StringType,true)))

# %%
times_2020_df = times_2020_df.withColumnRenamed('atletas.clube_id', 'Abreviacao')
times_2020_df = times_2020_df.withColumnRenamed('atletas.clube.id.full.name', 'Nome')

# %%
times_2020_df = times_2020_df['Abreviacao', 'Nome']
times_2020_df = times_2020_df.dropDuplicates(['Abreviacao', 'Nome'])
times_2020_df.toPandas()
# Out:
#    Abreviacao           Nome
# 0         354          Ceará
# 1         373    Atlético-GO
# 2         284         Grêmio
# 3         277         Santos
# 4         276      São Paulo
# 5         282    Atlético-MG
# 6         267          Vasco
# 7         262       Flamengo
# 8         285  Internacional
# 9         263       Botafogo
# 10        292          Sport
# 11        266     Fluminense
# 12        290          Goiás
# 13        280     Bragantino
# 14        356      Fortaleza
# 15        265          Bahia
# 16        294       Coritiba
# 17        293   Athlético-PR
# 18        264    Corinthians
# 19        275      Palmeiras

# %%
#Ler tabela de referencia Times_ids
times_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/times_ids.csv", header=True)
times_df = times_df.withColumnRenamed('abreviacao', 'abbr')
times_df.limit(5).toPandas()
# Out:
#         nome.cbf nome.cartola        nome.completo cod.older cod.2017  \
# 0   América - MG   América-MG           America MG       327      327
# 1   America - RN  Atlético-RN           America RN       200      200
# 2  Atlético - GO  Atlético-GO          Atletico GO       201      373
# 3  Atlético - MG  Atlético-MG     Atletico Mineiro       282      282
# 4  Atlético - PR  Atlético-PR  Atletico Paranaense       293      293
#
#   cod.2018   id abbr                                      escudos.60x60  \
# 0      327  327  AME  https://s.glbimg.com/es/sde/f/organizacoes/201...
# 1        1  200  OUT                                               None
# 2      373  373  ATL                                               None
# 3      282  282  ATL  https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 4      293  293  ATL  https://s.glbimg.com/es/sde/f/equipes/2015/06/...
#
#                                        escudos.45x45  \
# 0  https://s.glbimg.com/es/sde/f/organizacoes/201...
# 1                                               None
# 2                                               None
# 3  https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 4  https://s.glbimg.com/es/sde/f/equipes/2015/06/...
#
#                                        escudos.30x30
# 0  https://s.glbimg.com/es/sde/f/organizacoes/201...
# 1                                               None
# 2                                               None
# 3  https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 4  https://s.glbimg.com/es/sde/f/equipes/2015/06/...

# %%
times_df = times_df.withColumnRenamed('nome.cartola', 'ncartola')

# %%
times = times_2020_df.join(times_df, times_2020_df.Nome == times_df.ncartola)

times.toPandas()
# Out:
#    Abreviacao           Nome            nome.cbf       ncartola  \
# 0         354          Ceará          Ceará - CE          Ceará
# 1         373    Atlético-GO       Atlético - GO    Atlético-GO
# 2         284         Grêmio         Grêmio - RS         Grêmio
# 3         277         Santos         Santos - SP         Santos
# 4         276      São Paulo      São Paulo - SP      São Paulo
# 5         282    Atlético-MG       Atlético - MG    Atlético-MG
# 6         267          Vasco  Vasco da Gama - RJ          Vasco
# 7         262       Flamengo       Flamengo - RJ       Flamengo
# 8         285  Internacional  Internacional - RS  Internacional
# 9         263       Botafogo       Botafogo - RJ       Botafogo
# 10        292          Sport          Sport - PE          Sport
# 11        266     Fluminense     Fluminense - RJ     Fluminense
# 12        290          Goiás          Goiás - GO          Goiás
# 13        356      Fortaleza           Fortaleza      Fortaleza
# 14        265          Bahia          Bahia - BA          Bahia
# 15        294       Coritiba       Coritiba - PR       Coritiba
# 16        293   Athlético-PR        Athlético-PR   Athlético-PR
# 17        264    Corinthians    Corinthians - SP    Corinthians
# 18        275      Palmeiras      Palmeiras - SP      Palmeiras
#
#           nome.completo cod.older cod.2017 cod.2018   id abbr  \
# 0              Ceara SC       204      204      354  354  CEA
# 1           Atletico GO       201      373      373  373  ATL
# 2   Gremio Porto Alegre       284      284      284  284  GRE
# 3             Santos FC       277      277      277  277  SAN
# 4          Sao Paulo FC       276      276      276  276  SAO
# 5      Atletico Mineiro       282      282      282  282  ATL
# 6         Vasco da Gama       221      267      267  267  VAS
# 7           Flamengo RJ       262      262      262  262  FLA
# 8         Internacional       285      285      285  285  INT
# 9           Botafogo RJ       263      263      263  263  BOT
# 10    Sport Club Recife       292      292      292  292  SPO
# 11        Fluminense RJ       266      266      266  266  FLU
# 12             Goias EC       210      210      290  290  GOI
# 13            Fortaleza       209      209      356  356  FOR
# 14             EC Bahia       207      265      265  265  BAH
# 15          Coritiba FC       294      294      294  294  COR
# 16  Atletico Paranaense       293      293      293  293  ATL
# 17       Corinthians SP       264      264      264  264  COR
# 18         SE Palmeiras       275      275      275  275  PAL
#
#                                         escudos.60x60  \
# 0   https://s.glbimg.com/es/sde/f/equipes/2018/05/...
# 1                                                None
# 2   https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 3   https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 4   https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 5   https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 6   https://s.glbimg.com/es/sde/f/equipes/2016/07/...
# 7   https://s.glbimg.com/es/sde/f/equipes/2018/04/...
# 8   https://s.glbimg.com/es/sde/f/equipes/2016/05/...
# 9   https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 10  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 11  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 12                                               None
# 13                                               None
# 14  https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 15                                               None
# 16                                               None
# 17  https://s.glbimg.com/es/sde/f/equipes/2014/04/...
# 18  https://s.glbimg.com/es/sde/f/equipes/2014/04/...
#
#                                         escudos.45x45  \
# 0   https://s.glbimg.com/es/sde/f/equipes/2018/05/...
# 1                                                None
# 2   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 3   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 4   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 5   https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 6   https://s.glbimg.com/es/sde/f/equipes/2016/07/...
# 7   https://s.glbimg.com/es/sde/f/equipes/2018/04/...
# 8   https://s.glbimg.com/es/sde/f/equipes/2016/05/...
# 9   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 10  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 11  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 12                                               None
# 13                                               None
# 14  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 15                                               None
# 16                                               None
# 17  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 18  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
#
#                                         escudos.30x30
# 0   https://s.glbimg.com/es/sde/f/equipes/2018/05/...
# 1                                                None
# 2   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 3   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 4   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 5   https://s.glbimg.com/es/sde/f/equipes/2017/11/...
# 6   https://s.glbimg.com/es/sde/f/equipes/2016/07/...
# 7   https://s.glbimg.com/es/sde/f/equipes/2018/04/...
# 8   https://s.glbimg.com/es/sde/f/equipes/2016/05/...
# 9   https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 10  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 11  https://s.glbimg.com/es/sde/f/equipes/2015/07/...
# 12                                               None
# 13                                               None
# 14  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 15                                               None
# 16                                               None
# 17  https://s.glbimg.com/es/sde/f/equipes/2013/12/...
# 18  https://s.glbimg.com/es/sde/f/equipes/2013/12/...

# %%
times = times['Abreviacao', 'Nome', 'id']
times.toPandas()
# Out:
#    Abreviacao           Nome   id
# 0         354          Ceará  354
# 1         373    Atlético-GO  373
# 2         284         Grêmio  284
# 3         277         Santos  277
# 4         276      São Paulo  276
# 5         282    Atlético-MG  282
# 6         267          Vasco  267
# 7         262       Flamengo  262
# 8         285  Internacional  285
# 9         263       Botafogo  263
# 10        292          Sport  292
# 11        266     Fluminense  266
# 12        290          Goiás  290
# 13        356      Fortaleza  356
# 14        265          Bahia  265
# 15        294       Coritiba  294
# 16        293   Athlético-PR  293
# 17        264    Corinthians  264
# 18        275      Palmeiras  275

# %%
times_2020_df = times.dropDuplicates(['Abreviacao', 'Nome', 'id'])

# %%
times_2020_df = times_2020_df.withColumnRenamed('id', 'ID')
times_2020_df.toPandas()
# Out:
#    Abreviacao           Nome   ID
# 0         354          Ceará  354
# 1         373    Atlético-GO  373
# 2         284         Grêmio  284
# 3         277         Santos  277
# 4         276      São Paulo  276
# 5         282    Atlético-MG  282
# 6         267          Vasco  267
# 7         262       Flamengo  262
# 8         285  Internacional  285
# 9         263       Botafogo  263
# 10        292          Sport  292
# 11        266     Fluminense  266
# 12        290          Goiás  290
# 13        356      Fortaleza  356
# 14        265          Bahia  265
# 15        294       Coritiba  294
# 16        293   Athlético-PR  293
# 17        264    Corinthians  264
# 18        275      Palmeiras  275

# %%
#Adiciona coluna ANO = 2020
times_2020_df = times_2020_df.withColumn('year', lit(2020))
times_2020_df.toPandas()
# Out:
#    Abreviacao           Nome   ID  year
# 0         354          Ceará  354  2020
# 1         373    Atlético-GO  373  2020
# 2         284         Grêmio  284  2020
# 3         277         Santos  277  2020
# 4         276      São Paulo  276  2020
# 5         282    Atlético-MG  282  2020
# 6         267          Vasco  267  2020
# 7         262       Flamengo  262  2020
# 8         285  Internacional  285  2020
# 9         263       Botafogo  263  2020
# 10        292          Sport  292  2020
# 11        266     Fluminense  266  2020
# 12        290          Goiás  290  2020
# 13        356      Fortaleza  356  2020
# 14        265          Bahia  265  2020
# 15        294       Coritiba  294  2020
# 16        293   Athlético-PR  293  2020
# 17        264    Corinthians  264  2020
# 18        275      Palmeiras  275  2020

# %%
times_2020_df.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/times/')
#transforma arquivo em parquet
times_2020_parquet = spark.read.option('basePath', '/cartola/clean/times/').parquet('/cartola/clean/times/*')

# %%
times_2020_parquet.toPandas()
# Out:
#        ID         Nome Abreviacao           Slug  year
# 0     373  Atlético-GO        ATL  Atlético - GO  2017
# 1     282  Atlético-MG        ATL  Atlético - MG  2017
# 2     293  Atlético-PR        ATL  Atlético - PR  2017
# 3     314         Avaí        AVA      Avaí - SC  2017
# 4     265        Bahia        BAH     Bahia - BA  2017
# ..    ...          ...        ...            ...   ...
# 133  None     Botafogo        263           None  2019
# 134  None         Avaí        314           None  2019
# 135  None        Vasco        267           None  2019
# 136  None        Bahia        265           None  2019
# 137  None          CSA        341           None  2019
#
# [138 rows x 5 columns]

# %% [markdown]
# ## scouts_raw

# %%
# Analisando o arquivo 2014_lances.csv vimos que não é necessário processar esse arquivo, pois as informações relevantes estão em scouts_raw.

# %%
scouts_raw_2020_df = spark.read.option("encoding", "UTF-8").csv("/cartola/data/2020/rodada-*.csv", header=True)

# %%
scouts_raw_2020_ano = scouts_raw_2020_df.withColumn('year', lit(2020))

# %%
scouts_raw_2020_ano.schema
# Out:
# StructType(List(StructField(_c0,StringType,true),StructField(atletas.nome,StringType,true),StructField(atletas.slug,StringType,true),StructField(atletas.apelido,StringType,true),StructField(atletas.foto,StringType,true),StructField(atletas.atleta_id,StringType,true),StructField(atletas.rodada_id,StringType,true),StructField(atletas.clube_id,StringType,true),StructField(atletas.posicao_id,StringType,true),StructField(atletas.status_id,StringType,true),StructField(atletas.pontos_num,StringType,true),StructField(atletas.preco_num,StringType,true),StructField(atletas.variacao_num,StringType,true),StructField(atletas.media_num,StringType,true),StructField(atletas.jogos_num,StringType,true),StructField(atletas.clube.id.full.name,StringType,true),StructField(CA,StringType,true),StructField(DS,StringType,true),StructField(FC,StringType,true),StructField(FD,StringType,true),StructField(FF,StringType,true),StructField(FS,StringType,true),StructField(G,StringType,true),StructField(I,StringType,true),StructField(PI,StringType,true),StructField(A,StringType,true),StructField(SG,StringType,true),StructField(DD,StringType,true),StructField(DP,StringType,true),StructField(GS,StringType,true),StructField(FT,StringType,true),StructField(PP,StringType,true),StructField(CV,StringType,true),StructField(GC,StringType,true),StructField(year,IntegerType,false)))

# %%
scouts_raw_2020_ano.toPandas()
# Out:
#        _c0                        atletas.nome      atletas.slug  \
# 0        1             Augusto Sérgio Ferreira     guto-ferreira
# 1        2  Rafael Martiniano de Miranda Moura      rafael-moura
# 2        3                       Cícero Santos            cicero
# 3        4   Marcelo Augusto Oliveira Chamusca  marcelo-chamusca
# 4        5             Jonathan Cícero Moreira          jonathan
# ...    ...                                 ...               ...
# 29073  805          Abel Carlos da Silva Braga        abel-braga
# 29074  806               Matheus Sousa Pereira           pereira
# 29075  807       Julimar Silva Oliveira Júnior           julimar
# 29076  808            Marino Hinestroza Angulo            marino
# 29077  809           Geovane da Silva de Souza           geovane
#
#         atletas.apelido                                       atletas.foto  \
# 0         Guto Ferreira  https://s.glbimg.com/es/sde/f/2020/07/19/37fe3...
# 1          Rafael Moura  https://s.glbimg.com/es/sde/f/2020/08/26/6c384...
# 2                Cícero  https://s.glbimg.com/es/sde/f/2019/03/22/127a9...
# 3      Marcelo Chamusca  https://s.glbimg.com/es/sde/f/2019/04/18/bb15f...
# 4              Jonathan  https://s.glbimg.com/es/sde/f/2019/03/30/8b565...
# ...                 ...                                                ...
# 29073        Abel Braga  https://s.glbimg.com/es/sde/f/2020/11/10/0f92e...
# 29074           Pereira  https://s.glbimg.com/es/sde/f/2020/11/13/9dbc9...
# 29075           Julimar  https://s.glbimg.com/es/sde/f/2021/02/20/de210...
# 29076            Marino  https://s.glbimg.com/es/sde/f/2020/11/11/7f4b5...
# 29077           Geovane  https://s.glbimg.com/es/sde/f/2021/02/20/c227e...
#
#       atletas.atleta_id atletas.rodada_id atletas.clube_id atletas.posicao_id  \
# 0                 37245                25              354                tec
# 1                 37655                25              290                ata
# 2                 37688                25              263                mei
# 3                 37319                25              356                tec
# 4                 37662                25              293                lat
# ...                 ...               ...              ...                ...
# 29073             40006                37              285                tec
# 29074             97711                37              373                zag
# 29075            102796                37              293                ata
# 29076            110598                37              275                ata
# 29077            105336                37              354                mei
#
#       atletas.status_id  ...     A    SG    DD    DP    GS    FT    PP    CV  \
# 0              Provável  ...    NA    NA    NA    NA    NA    NA    NA    NA
# 1              Provável  ...    NA    NA    NA    NA    NA    NA    NA    NA
# 2                  Nulo  ...    NA    NA    NA    NA    NA    NA    NA    NA
# 3              Provável  ...    NA    NA    NA    NA    NA    NA    NA    NA
# 4                  Nulo  ...     1     4    NA    NA    NA    NA    NA    NA
# ...                 ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 29073          Provável  ...  None  None  None  None  None  None  None  None
# 29074              Nulo  ...  None  None  None  None  None  None  None  None
# 29075              Nulo  ...  None  None  None  None  None  None  None  None
# 29076              Nulo  ...  None  None  None  None  None  None  None  None
# 29077              Nulo  ...  None  None  None  None  None  None  None  None
#
#          GC  year
# 0        NA  2020
# 1        NA  2020
# 2        NA  2020
# 3        NA  2020
# 4        NA  2020
# ...     ...   ...
# 29073  None  2020
# 29074  None  2020
# 29075  None  2020
# 29076  None  2020
# 29077  None  2020
#
# [29078 rows x 35 columns]

# %%
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.atleta_id', 'AtletaID')
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.clube_id', 'ClubeID')
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.pontos_num', 'Pontos')
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.preco_num', 'Preco')
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.variacao_num', 'PrecoVariacao')
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.preco_num', 'Preco')

# %%
scouts_raw_2020_ano = scouts_raw_2020_ano.drop('scout', 'atletas.apelido', 'atletas.clube.id.full.name', 'atletas.foto', 'atletas.jogos_num', 'atletas.nome', 'atletas.posicao_id', 'atletas.status_id',  )

# %%
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumn("Pontos", scouts_raw_2020_ano["Pontos"].cast(FloatType()))

# %%
scouts_raw_2020_ano.toPandas()
# Out:
#        _c0      atletas.slug AtletaID atletas.rodada_id ClubeID  Pontos  \
# 0        1     guto-ferreira    37245                25     354    3.83
# 1        2      rafael-moura    37655                25     290   -0.90
# 2        3            cicero    37688                25     263    0.00
# 3        4  marcelo-chamusca    37319                25     356    2.23
# 4        5          jonathan    37662                25     293    0.00
# ...    ...               ...      ...               ...     ...     ...
# 29073  805        abel-braga    40006                37     285    0.00
# 29074  806           pereira    97711                37     373    0.00
# 29075  807           julimar   102796                37     293    0.00
# 29076  808            marino   110598                37     275    0.00
# 29077  809           geovane   105336                37     354    0.00
#
#        Preco PrecoVariacao atletas.media_num  CA  ...     A    SG    DD    DP  \
# 0       9.38         -0.52              3.79  NA  ...    NA    NA    NA    NA
# 1       5.39         -1.31              1.77   5  ...    NA    NA    NA    NA
# 2       4.72             0              0.67  NA  ...    NA    NA    NA    NA
# 3       7.13         -0.46              2.79  NA  ...    NA    NA    NA    NA
# 4       9.64             0              3.07   2  ...     1     4    NA    NA
# ...      ...           ...               ...  ..  ...   ...   ...   ...   ...
# 29073  11.22         -0.24              3.73  NA  ...  None  None  None  None
# 29074   4.65             0              3.44  NA  ...  None  None  None  None
# 29075      1             0                 0  NA  ...  None  None  None  None
# 29076      1             0                 0  NA  ...  None  None  None  None
# 29077      1             0                 0  NA  ...  None  None  None  None
#
#          GS    FT    PP    CV    GC  year
# 0        NA    NA    NA    NA    NA  2020
# 1        NA    NA    NA    NA    NA  2020
# 2        NA    NA    NA    NA    NA  2020
# 3        NA    NA    NA    NA    NA  2020
# 4        NA    NA    NA    NA    NA  2020
# ...     ...   ...   ...   ...   ...   ...
# 29073  None  None  None  None  None  2020
# 29074  None  None  None  None  None  2020
# 29075  None  None  None  None  None  2020
# 29076  None  None  None  None  None  2020
# 29077  None  None  None  None  None  2020
#
# [29078 rows x 28 columns]

# %%
scouts_raw_2020_ano.schema
# Out:
# StructType(List(StructField(_c0,StringType,true),StructField(atletas.slug,StringType,true),StructField(AtletaID,StringType,true),StructField(atletas.rodada_id,StringType,true),StructField(ClubeID,StringType,true),StructField(Pontos,FloatType,true),StructField(Preco,StringType,true),StructField(PrecoVariacao,StringType,true),StructField(atletas.media_num,StringType,true),StructField(CA,StringType,true),StructField(DS,StringType,true),StructField(FC,StringType,true),StructField(FD,StringType,true),StructField(FF,StringType,true),StructField(FS,StringType,true),StructField(G,StringType,true),StructField(I,StringType,true),StructField(PI,StringType,true),StructField(A,StringType,true),StructField(SG,StringType,true),StructField(DD,StringType,true),StructField(DP,StringType,true),StructField(GS,StringType,true),StructField(FT,StringType,true),StructField(PP,StringType,true),StructField(CV,StringType,true),StructField(GC,StringType,true),StructField(year,IntegerType,false)))

# %%
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.rodada_id', 'Rodada')
scouts_raw_2020_ano = scouts_raw_2020_ano.withColumnRenamed('atletas.media_num', 'PontosMedia')

# %%
scouts_raw_2020_ano = scouts_raw_2020_ano.drop('_c0', 'atletas.slug', 'atletas.posicao_id', 'atletas.status_id')
scouts_raw_2020_ano.toPandas()
# Out:
#       AtletaID Rodada ClubeID  Pontos  Preco PrecoVariacao PontosMedia  CA  \
# 0        37245     25     354    3.83   9.38         -0.52        3.79  NA
# 1        37655     25     290   -0.90   5.39         -1.31        1.77   5
# 2        37688     25     263    0.00   4.72             0        0.67  NA
# 3        37319     25     356    2.23   7.13         -0.46        2.79  NA
# 4        37662     25     293    0.00   9.64             0        3.07   2
# ...        ...    ...     ...     ...    ...           ...         ...  ..
# 29073    40006     37     285    0.00  11.22         -0.24        3.73  NA
# 29074    97711     37     373    0.00   4.65             0        3.44  NA
# 29075   102796     37     293    0.00      1             0           0  NA
# 29076   110598     37     275    0.00      1             0           0  NA
# 29077   105336     37     354    0.00      1             0           0  NA
#
#          DS    FC  ...     A    SG    DD    DP    GS    FT    PP    CV    GC  \
# 0        NA    NA  ...    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 1         5    30  ...    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 2         1    NA  ...    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 3        NA    NA  ...    NA    NA    NA    NA    NA    NA    NA    NA    NA
# 4         8     4  ...     1     4    NA    NA    NA    NA    NA    NA    NA
# ...     ...   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 29073  None  None  ...  None  None  None  None  None  None  None  None  None
# 29074  None  None  ...  None  None  None  None  None  None  None  None  None
# 29075  None  None  ...  None  None  None  None  None  None  None  None  None
# 29076  None  None  ...  None  None  None  None  None  None  None  None  None
# 29077  None  None  ...  None  None  None  None  None  None  None  None  None
#
#        year
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
# ...     ...
# 29073  2020
# 29074  2020
# 29075  2020
# 29076  2020
# 29077  2020
#
# [29078 rows x 26 columns]

# %%
scouts_raw_2020_ano.write.mode('overwrite').partitionBy('year').parquet('/cartola/clean/scouts/')
#transforma arquivo em parquet
scouts_raw_2020_ano = spark.read.option('basePath', '/cartola/clean/scouts/').parquet('/cartola/clean/scouts/*')

# %%
scouts_raw_2020_ano.toPandas()
# Out:
#        AtletaID Rodada ClubeID Participou Posicao Jogos  Pontos PontosMedia  \
# 0         36540      0     FLA       None    None  None     0.0        None
# 1         36612      0     PAL       None    None  None     0.0        None
# 2         36943      0     ATL       None    None  None     0.0        None
# 3         37245      0     BAH       None    None  None     0.0        None
# 4         37246      0     SPO       None    None  None     0.0        None
# ...         ...    ...     ...        ...     ...   ...     ...         ...
# 216262    40006     37     285       None    None  None     0.0        3.73
# 216263    97711     37     373       None    None  None     0.0        3.44
# 216264   102796     37     293       None    None  None     0.0           0
# 216265   110598     37     275       None    None  None     0.0           0
# 216266   105336     37     354       None    None  None     0.0           0
#
#         Preco PrecoVariacao  ...    RB    FC    GC    CA    CV    SG    DD  \
# 0           5             0  ...  None  None  None  None  None  None  None
# 1           8             0  ...  None  None  None  None  None  None  None
# 2          10             0  ...  None  None  None  None  None  None  None
# 3           4             0  ...  None  None  None  None  None  None  None
# 4           4             0  ...  None  None  None  None  None  None  None
# ...       ...           ...  ...   ...   ...   ...   ...   ...   ...   ...
# 216262  11.22         -0.24  ...  None  None  None    NA  None  None  None
# 216263   4.65             0  ...  None  None  None    NA  None  None  None
# 216264      1             0  ...  None  None  None    NA  None  None  None
# 216265      1             0  ...  None  None  None    NA  None  None  None
# 216266      1             0  ...  None  None  None    NA  None  None  None
#
#           DP    GS  year
# 0       None  None  2017
# 1       None  None  2017
# 2       None  None  2017
# 3       None  None  2017
# 4       None  None  2017
# ...      ...   ...   ...
# 216262  None  None  2020
# 216263  None  None  2020
# 216264  None  None  2020
# 216265  None  None  2020
# 216266  None  None  2020
#
# [216267 rows x 35 columns]

# %%
# -        Quantas partidas resultaram em empate?
pontos_por_atleta = scouts_raw_2020_ano[scouts_raw_2020_ano['year'] == 2020]

jogadores_2020 = jogadores_2020_parquet[jogadores_2020_parquet['year'] == 2020]

pontos_por_atleta = pontos_por_atleta.groupBy("AtletaID").agg(sum("Pontos").alias("SomaPontos"))

#count_result = count_result.withColumn('total_wins', count_result['count(1)'])

pontos_por_atleta = pontos_por_atleta.sort(pontos_por_atleta.SomaPontos.desc())

#count_result = count_result.drop('count(1)')

#count_result.show(5)


pontos_por_atleta.toPandas()
# Out:
#      AtletaID  SomaPontos
# 0       68952  254.700000
# 1       92630  230.000001
# 2       71844  195.800000
# 3       71162  193.500001
# 4       86485  187.200000
# ...       ...         ...
# 1008   106843   -5.800000
# 1009    71640   -6.600000
# 1010    72595   -7.800000
# 1011    52950   -9.200000
# 1012    62129  -19.200000
#
# [1013 rows x 2 columns]

# %%
scouts_atletas = pontos_por_atleta.join(jogadores_2020, pontos_por_atleta.AtletaID == jogadores_2020.ID)
scouts_atletas = scouts_atletas.sort(scouts_atletas.SomaPontos.desc())
scouts_atletas.toPandas()
# Out:
#     AtletaID  SomaPontos      ID             Apelido ClubeID PosicaoID  year
# 0      68952  254.700000   68952             Marinho     277         5  2020
# 1      92630  230.000001   92630           Claudinho     280         5  2020
# 2      71844  195.800000   71844     Thiago Galhardo     285         4  2020
# 3      71162  193.500001   71162            Vinícius     354         4  2020
# 4      86485  187.200000   86485                Keno     282         5  2020
# ..       ...         ...     ...                 ...     ...       ...   ...
# 594   106843   -5.800000  106843             Borrero     282         4  2020
# 595    71640   -6.600000   71640       Ronaldo Silva     292         5  2020
# 596    72595   -7.800000   72595  Maurício Kozlinski     373         1  2020
# 597    52950   -9.200000   52950              Victor     282         1  2020
# 598    62129  -19.200000   62129          Wellington     293         4  2020
#
# [599 rows x 7 columns]

# %% [markdown]
# ## DEMONSTRAÇÃO

# %%
partidas_2014_df = spark.read.csv("/cartola/data/2014/2014_jogadores.csv", header=True)
partidas_2014_ct = partidas_2014_df.withColumn('time', regexp_replace('home_team', ' - RJ', ''))
final_partidas = partidas_2014_ct.withColumn('time_low', lower(col('time'))).show(truncate=False)

# %%
with_ano_partidas = partidas_2014_ct.withColumn('ano', lit(2014)).show(truncate=False)
with_ano_partidas.show()

# %%
Comando para sobrescrever arquivo caso já existente.
Agrupar scouts por ID e contar (caso tenha duplicidade)

# %%
inner_join = partidas_ids_2014_ano.join(times_2014_ano, partidas_ids_2014_ano.Casa == times_2014_ano.ID)
inner_join.toPandas()
# Out:
#          ID Rodada Casa Visitante PlacarCasa PlacarVisitante  Resultado   ano  \
# 0    179872      1  262       290          0               0     Empate  2014
# 1    179873      1  266       316          3               0       Casa  2014
# 2    179874      1  276       263          3               0       Casa  2014
# 3    179875      1  277       292          1               1     Empate  2014
# 4    179876      1  293       284          1               0       Casa  2014
# ..      ...    ...  ...       ...        ...             ...        ...   ...
# 375  180250     29  282       315          1               0       Casa  2014
# 376  180251     29  287       283          0               1  Visitante  2014
# 377  180252     29  285       264          1               2  Visitante  2014
# 378  180253     29  316       294          4               0       Casa  2014
# 379  180254     29  290       284          0               0     Empate  2014
#
#       ID           Nome Abreviacao           Slug   ano
# 0    262       flamengo        FLA       flamengo  2014
# 1    266     fluminense        FLU     fluminense  2014
# 2    276      são paulo        SAO      sao-paulo  2014
# 3    277         santos        SAN         santos  2014
# 4    293    atlético-pr        CAP    atletico-pr  2014
# ..   ...            ...        ...            ...   ...
# 375  282    atlético-mg        CAM    atletico-mg  2014
# 376  287        vitória        VIT        vitoria  2014
# 377  285  internacional        INT  internacional  2014
# 378  316    figueirense        FIG    figueirense  2014
# 379  290          goiás        GOI          goias  2014
#
# [380 rows x 13 columns]

# %%
scouts_atletas = pontos_por_atleta.join(jogadores_2014_parquet, pontos_por_atleta.Atleta == jogadores_2014_parquet.ID)
scouts_atletas = scouts_atletas.sort(scouts_atletas.SomaPontos.desc())
scouts_atletas.toPandas()

# %%
# -        Quantas partidas resultaram em empate?
pontos_por_atleta = scouts_raw_2014_ano.groupBy("Atleta").agg(sum("Pontos").alias("SomaPontos"))

#count_result = count_result.withColumn('total_wins', count_result['count(1)'])

pontos_por_atleta = pontos_por_atleta.sort(pontos_por_atleta.SomaPontos.desc())

#count_result = count_result.drop('count(1)')

#count_result.show(5)


pontos_por_atleta.toPandas()
